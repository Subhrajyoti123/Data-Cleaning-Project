# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Downloads/food_coded.csv")

# %%
data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
data.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
data.isnull()
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
data.iloc[:,1]
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 120    1
# 121    1
# 122    1
# 123    2
# 124    1
# Name: Gender, Length: 125, dtype: int64

# %%
dup_cols = set()

for x in range(data.shape[1]):
    base_col = data.iloc[:,x]
    for y in range(x+1,data.shape[1]):
        comp_col = data.iloc[:,y]
        
        if base_col.equals(comp_col):
            dup_cols.add(data.columns.values[y])
            
print(dup_cols)
# Out:
# set()

# %%
data.drop(labels= dup_cols, axis=1)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
data.isnull()
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
data.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
data['type_sports'] = pd.to_numeric(data['type_sports'],errors='coerce')

# %%
# Impute missing type_sports with median (Numerical Variable)

data["type_sports"].fillna(data["type_sports"].median(), inplace = True)

# %%
# Impute missing type_sports with median (Numerical Variable)

data["calories_day"].fillna(data["calories_day"].mode() [0], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# GPA                   2
# Gender                0
# breakfast             0
# calories_chicken      0
# calories_day          0
#                    ...
# type_sports         125
# veggies_day           0
# vitamins              0
# waffle_calories       0
# weight                2
# Length: 61, dtype: int64

# %%
# Impute missing type_sports with median (Numerical Variable)

data["type_sports"].fillna(data["type_sports"].mean(), inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# GPA                   2
# Gender                0
# breakfast             0
# calories_chicken      0
# calories_day          0
#                    ...
# type_sports         125
# veggies_day           0
# vitamins              0
# waffle_calories       0
# weight                2
# Length: 61, dtype: int64

# %%
# Using replace()
data["type_sports"].replace(np.NaN,data["type_sports"].mean(), inplace = True)

# %%
data["GPA"].replace(np.NaN,data["GPA"].mode() [0], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# GPA                   0
# Gender                0
# breakfast             0
# calories_chicken      0
# calories_day          0
#                    ...
# type_sports         125
# veggies_day           0
# vitamins              0
# waffle_calories       0
# weight                2
# Length: 61, dtype: int64

# %%
data["weight"].replace(np.NaN,data["weight"].mode() [0], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# GPA                   0
# Gender                0
# breakfast             0
# calories_chicken      0
# calories_day          0
#                    ...
# type_sports         125
# veggies_day           0
# vitamins              0
# waffle_calories       0
# weight                0
# Length: 61, dtype: int64

# %%
data = data.dropna(axis=1, how='all')

# %%
data.isnull().sum()
# Out:
# GPA                              0
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                     0
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             1
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# ...

# %%
data["calories_day"].replace(np.NaN,data["calories_day"].mode() [0], inplace = True)

# %%
data["cuisine"].replace(np.NaN,data["cuisine"].mean(), inplace = True)

# %%
data["comfort_food_reasons_coded"].fillna(data["comfort_food_reasons_coded"].median(), inplace = True)

# %%
data["exercise"].fillna(data["exercise"].median(), inplace = True)

# %%
data["cook"].replace(np.NaN,data["cook"].mode() [0], inplace = True)

# %%
data["drink"].replace(np.NaN,data["drink"].mean(), inplace = True)

# %%
data["father_education"].fillna(data["father_education"].median(), inplace = True)

# %%
data["father_profession"].replace(np.NaN,data["father_profession"].mode() [0], inplace = True)

# %%
data["fav_food"].replace(np.NaN,data["fav_food"].mean(), inplace = True)

# %%
data["food_childhood"].replace(np.NaN,data["food_childhood"].mode() [0], inplace = True)

# %%
data["income"].fillna(data["income"].median(), inplace = True)

# %%
data["life_rewarding"].replace(np.NaN,data["life_rewarding"].mean(), inplace = True)

# %%
data["employment"].fillna(data["employment"].median(), inplace = True)

# %%
data["marital_status"].replace(np.NaN,data["marital_status"].mode() [0], inplace = True)

# %%
data["mother_education"].replace(np.NaN,data["mother_education"].mean(), inplace = True)

# %%
data["on_off_campus"].fillna(data["on_off_campus"].median(), inplace = True)

# %%
data["persian_food"].replace(np.NaN,data["persian_food"].mode() [0], inplace = True)

# %%
data["self_perception_weight"].replace(np.NaN,data["self_perception_weight"].mean(), inplace = True)

# %%
data["soup"].fillna(data["soup"].median(), inplace = True)

# %%
data["sports"].replace(np.NaN,data["sports"].mode() [0], inplace = True)

# %%
data["tortilla_calories"].replace(np.NaN,data["tortilla_calories"].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  1
# coffee                          0
# comfort_food                    1
# comfort_food_reasons            1
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    1
# diet_current_coded              0
# drink                           0
# eating_changes                  3
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     2
# fav_cuisine_coded               0
# ...

# %%
data = data.dropna(axis=1, thresh=1)

# %%
data.isnull().sum()
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  1
# coffee                          0
# comfort_food                    1
# comfort_food_reasons            1
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    1
# diet_current_coded              0
# drink                           0
# eating_changes                  3
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     2
# fav_cuisine_coded               0
# ...

# %%
data.dropna(subset=['calories_scone'], inplace=True)

# %%
data.dropna(subset=['comfort_food'], inplace=True)

# %%
data.dropna(subset=['comfort_food_reasons'], inplace=True)

# %%
data.dropna(subset=['diet_current'], inplace=True)

# %%
data.dropna(subset=['eating_changes'], inplace=True)

# %%
data.dropna(subset=['fav_cuisine'], inplace=True)

# %%
data.dropna(subset=['healthy_meal'], inplace=True)

# %%
data.dropna(subset=['ideal_diet'], inplace=True)

# %%
data.dropna(subset=['meals_dinner_friend'], inplace=True)

# %%
data.dropna(subset=['mother_profession'], inplace=True)

# %%
data.isnull().sum()
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  0
# coffee                          0
# comfort_food                    0
# comfort_food_reasons            0
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    0
# diet_current_coded              0
# drink                           0
# eating_changes                  0
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     0
# fav_cuisine_coded               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 124
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           118 non-null    object
#  1   Gender                        118 non-null    int64
#  2   breakfast                     118 non-null    int64
#  3   calories_chicken              118 non-null    int64
#  4   calories_day                  118 non-null    float64
#  5   calories_scone                118 non-null    float64
#  6   coffee                        118 non-null    int64
#  7   comfort_food                  118 non-null    object
#  8   comfort_food_reasons          118 non-null    object
#  9   comfort_food_reasons_coded    118 non-null    float64
#  10  cook                          118 non-null    float64
#  11  comfort_food_reasons_coded.1  118 non-null    int64
# ...
